# %% [markdown]
# # Google search using pytrends

# %% [markdown]
# ### Pytrends is an unofficial Google Trends API that provides different methods to download reports of trending results from google trends. The python package can help you automate the process of fetching data and get the result over a short period of time.

# %%
# !pip install pytrends
# Out:
# Collecting pytrends
#   Downloading pytrends-4.8.0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests>=2.0 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (2.28.1)
# Requirement already satisfied: pandas>=0.25 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (1.2.4)
# Requirement already satisfied: lxml in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pytrends) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25->pytrends) (1.19.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2020.12.5)
# Requirement already satisfied: idna<4,>=2.5 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0->pytrends) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from requests>=2.0->pytrends) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/a/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.25->pytrends) (1.12.0)
# Building wheels for collected packages: pytrends
#   Building wheel for pytrends (setup.py) ... done
#   Created wheel for pytrends: filename=pytrends-4.8.0-py3-none-any.whl size=16105 sha256=75ee37b923ef317600a3ed1161a82cc5fbafe2f027239c3f505ee652fc80917e
#   Stored in directory: /Users/a/Library/Caches/pip/wheels/e8/78/c8/18d4f4804753e14416809b365773220c48b41fe5387f2bb6b9
# Successfully built pytrends
# Installing collected packages: pytrends
# Successfully installed pytrends-4.8.0
#
# [notice] A new release of pip available: 22.2 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=["Machine Learning"])
data = trends.interest_by_region()
data = data.sort_values(by="Machine Learning", ascending=False)
data = data.head(10)
print(data)
# Out:
#              Machine Learning
# geoName
# China                     100
# Singapore                  44
# Ethiopia                   38
# St. Helena                 33
# India                      31
# Hong Kong                  24
# Pakistan                   22
# Tunisia                    21
# Nepal                      21
# South Korea                20

# %%
data.reset_index().plot(x="geoName", y="Machine Learning", figsize=(20,15), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Machine Learning'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(20, 15))
data['Machine Learning'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Machine Learning', fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()
